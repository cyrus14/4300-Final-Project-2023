# %%
import csv
import pandas
import random

# %%
total_size = 10000

rap_prop = 0.330
rap_n = 0

rb_prop = 0.043
rb_n = 0

rock_prop = 0.156
rock_n = 0

pop_prop = 0.430
pop_n = 0

country_prop = 0.041
country_n = 0

saved_dicts = []

# %%
import pandas
import random

filename = "song_lyrics.csv"
n = 5000000
s = 20000 #desired sample size
skip = sorted(random.sample(range(1,n+1),n-s)) #the 0-indexed header will not be included in the skip list

# %%
df = pandas.read_csv(filename, skiprows=skip)

# %%
dfa = df.loc[df.language_cld3 == 'en']

# %%
dfa
# Out:
#                                        title      tag  \
# 0       One More Chance / Stay With Me Remix      rap
# 1                    Keep Their Heads Ringin      rap
# 2                                   Superman      rap
# 3                                Worst Enemy      rap
# 4                               White  Nerdy      rap
# ...                                      ...      ...
# 154847             Everything Is Alright Now      pop
# 154849                            White Lies      pop
# 154851                                 Ocean      pop
# 154853                       Raise Our Hands      pop
# 154855                            New Number  country
#
#                           artist  year    views  \
# 0           The Notorious B.I.G.  1995   583928
# 1                        Dr. Dre  1995   170514
# 2                         Eminem  2002  1516202
# 3                     Gucci Mane  2009    24426
# 4            "Weird Al" Yankovic  2006    89212
# ...

# %%
dfa.tag.value_counts()
# Out:
# pop        33659
# rap        30832
# rock       17699
# rb          5007
# country     2565
# misc        2121
# Name: tag, dtype: int64

# %%
dfa.sort_values(by='views', d)
# Out:
#                               title   tag                          artist  \
# 89117      Lady Linlithgows Mission  misc                Anthony Trollope
# 88971                 Poison Letter  rock  E [Zedek / Sanford / McCarthy]
# 74525   The Burger Sauce - Acapella   rap                   PrestonsStuff
# 88979                 Down She Goes  rock  E [Zedek / Sanford / McCarthy]
# 88980                    One In Two  rock  E [Zedek / Sanford / McCarthy]
# ...                             ...   ...                             ...
# 9741                           TATI   rap                         6ix9ine
# 7021     ​untitled 02 | 06.23.2014.   rap                  Kendrick Lamar
# 2                          Superman   rap                          Eminem
# 135557                    As It Was   pop                    Harry Styles
# 384                          1Train   rap                      A$AP Rocky
#
#         year    views                                           features  \
# ...

# %%
dfa.to_csv('song_lyrics_shortened_pd.csv')
